# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
# %matplotlib inline        
# with writing plt.show()

# %%
train_df =pd.read_excel("E:\\EDA_FE\\dataset\\Data_Train.xlsx")

# %%
test_df =pd.read_excel("E:\\EDA_FE\\dataset\\Test_set.xlsx")

# %%
test_df.head()
# Out:
#              Airline Date_of_Journey    Source Destination            Route  \
# 0        Jet Airways       6/06/2019     Delhi      Cochin  DEL → BOM → COK
# 1             IndiGo      12/05/2019   Kolkata    Banglore  CCU → MAA → BLR
# 2        Jet Airways      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 3  Multiple carriers      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 4           Air Asia      24/06/2019  Banglore       Delhi        BLR → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info
# 0    17:30  04:25 07 Jun  10h 55m      1 stop                      No info
# 1    06:20         10:20       4h      1 stop                      No info
# 2    19:15  19:00 22 May  23h 45m      1 stop  In-flight meal not included
# 3    08:00         21:00      13h      1 stop                      No info
# 4    23:55  02:45 25 Jun   2h 50m    non-stop                      No info

# %%
# merge both data 

final_df  = pd.concat([train_df,test_df], ignore_index=True)

# %%
final_df
# Out:
#                  Airline Date_of_Journey    Source Destination  \
# 0                 IndiGo      24/03/2019  Banglore   New Delhi
# 1              Air India       1/05/2019   Kolkata    Banglore
# 2            Jet Airways       9/06/2019     Delhi      Cochin
# 3                 IndiGo      12/05/2019   Kolkata    Banglore
# 4                 IndiGo      01/03/2019  Banglore   New Delhi
# ...                  ...             ...       ...         ...
# 13349          Air India       6/06/2019   Kolkata    Banglore
# 13350             IndiGo      27/03/2019   Kolkata    Banglore
# 13351        Jet Airways       6/03/2019     Delhi      Cochin
# 13352          Air India       6/03/2019     Delhi      Cochin
# 13353  Multiple carriers      15/06/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# ...

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13354 entries, 0 to 13353
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Date_of_Journey  13354 non-null  object
#  2   Source           13354 non-null  object
#  3   Destination      13354 non-null  object
#  4   Route            13353 non-null  object
#  5   Dep_Time         13354 non-null  object
#  6   Arrival_Time     13354 non-null  object
#  7   Duration         13354 non-null  object
#  8   Total_Stops      13353 non-null  object
#  9   Additional_Info  13354 non-null  object
#  10  Price            10683 non-null  float64
# dtypes: float64(1), object(10)
# memory usage: 1.1+ MB

# %%
final_df.isnull().sum()
# Out:
# Airline               0
# Date_of_Journey       0
# Source                0
# Destination           0
# Route                 1
# Dep_Time              0
# Arrival_Time          0
# Duration              0
# Total_Stops           1
# Additional_Info       0
# Price              2671
# dtype: int64

# %% [markdown]
# # Feature engineering

# %% [markdown]
# ##  converting a column in date time format

# %%
final_df['Date_of_Journey'].head()
# Out:
# 0    24/03/2019
# 1     1/05/2019
# 2     9/06/2019
# 3    12/05/2019
# 4    01/03/2019
# Name: Date_of_Journey, dtype: object

# %%
final_df['Date_of_Journey'].str.split('/').str[0]
# Out:
# 0        24
# 1         1
# 2         9
# 3        12
# 4        01
#          ..
# 13349     6
# 13350    27
# 13351     6
# 13352     6
# 13353    15
# Name: Date_of_Journey, Length: 13354, dtype: object

# %%
final_df["Date"]=final_df['Date_of_Journey'].str.split('/').str[0] 
final_df["Month"]=final_df['Date_of_Journey'].str.split('/').str[1]
final_df["Year"]=final_df['Date_of_Journey'].str.split('/').str[2]

# %%
final_df
# Out:
#                  Airline Date_of_Journey    Source Destination  \
# 0                 IndiGo      24/03/2019  Banglore   New Delhi
# 1              Air India       1/05/2019   Kolkata    Banglore
# 2            Jet Airways       9/06/2019     Delhi      Cochin
# 3                 IndiGo      12/05/2019   Kolkata    Banglore
# 4                 IndiGo      01/03/2019  Banglore   New Delhi
# ...                  ...             ...       ...         ...
# 13349          Air India       6/06/2019   Kolkata    Banglore
# 13350             IndiGo      27/03/2019   Kolkata    Banglore
# 13351        Jet Airways       6/03/2019     Delhi      Cochin
# 13352          Air India       6/03/2019     Delhi      Cochin
# 13353  Multiple carriers      15/06/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# ...

# %%
# df["Date"]=df['Date_of_Journey'].apply(lambda x:x.split("/")[0])
# df["Month"]=df['Date_of_Journey'].apply(lambda x:x.split("/")[1])
# df["Year"]=df['Date_of_Journey'].apply(lambda x:x.split("/")[2])

# %%
final_df["Date"] = final_df["Date"].astype(int)

final_df["Month"] = final_df["Month"].astype(int)

final_df["Year"] = final_df["Year"].astype(int)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13354 entries, 0 to 13353
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Date_of_Journey  13354 non-null  object
#  2   Source           13354 non-null  object
#  3   Destination      13354 non-null  object
#  4   Route            13353 non-null  object
#  5   Dep_Time         13354 non-null  object
#  6   Arrival_Time     13354 non-null  object
#  7   Duration         13354 non-null  object
#  8   Total_Stops      13353 non-null  object
#  9   Additional_Info  13354 non-null  object
#  10  Price            10683 non-null  float64
#  11  Date             13354 non-null  int32
#  12  Month            13354 non-null  int32
#  13  Year             13354 non-null  int32
# dtypes: float64(1), int32(3), object(10)
# memory usage: 1.3+ MB

# %%
final_df.drop('Date_of_Journey' , axis=1 , inplace=True)

# %%
final_df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#    Arrival_Time Duration Total_Stops Additional_Info    Price  Date  Month  \
# 0  01:10 22 Mar   2h 50m    non-stop         No info   3897.0    24      3
# 1         13:15   7h 25m     2 stops         No info   7662.0     1      5
# 2  04:25 10 Jun      19h     2 stops         No info  13882.0     9      6
# 3         23:30   5h 25m      1 stop         No info   6218.0    12      5
# 4         21:35   4h 45m      1 stop         No info  13302.0     1      3
#
#    Year
# 0  2019
# 1  2019
# 2  2019
# 3  2019
# 4  2019

# %%
final_df['Arrival_Time'].str.split(" ")  # see we require 1 index
# Out:
# 0        [01:10, 22, Mar]
# 1                 [13:15]
# 2        [04:25, 10, Jun]
# 3                 [23:30]
# 4                 [21:35]
#                ...
# 13349    [20:25, 07, Jun]
# 13350             [16:55]
# 13351    [04:25, 07, Mar]
# 13352             [19:15]
# 13353             [19:15]
# Name: Arrival_Time, Length: 13354, dtype: object

# %%
final_df['Arrival_Time']=final_df['Arrival_Time'].str.split(" ").str[0]

# %%
final_df['Arrival_Hour'] = final_df['Arrival_Time'].str.split(':').str[0]

final_df['Arrival_min'] = final_df['Arrival_Time'].str.split(':').str[1]

# %%
final_df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#   Arrival_Time Duration Total_Stops Additional_Info    Price  Date  Month  \
# 0        01:10   2h 50m    non-stop         No info   3897.0    24      3
# 1        13:15   7h 25m     2 stops         No info   7662.0     1      5
# 2        04:25      19h     2 stops         No info  13882.0     9      6
# 3        23:30   5h 25m      1 stop         No info   6218.0    12      5
# 4        21:35   4h 45m      1 stop         No info  13302.0     1      3
#
#    Year Arrival_Hour Arrival_min
# 0  2019           01          10
# 1  2019           13          15
# ...

# %%
final_df['Arrival_Hour']=final_df['Arrival_Hour'].astype(int)  

final_df['Arrival_min'] = final_df['Arrival_min'].astype(int)

# %%
final_df.drop('Arrival_Time' , axis=1 , inplace=True)

# %%
## do same with dept time col

# %%
final_df['Dept_hour']=final_df['Dep_Time'].str.split(':').str[0]
final_df['Dept_min']=final_df['Dep_Time'].str.split(':').str[1]
final_df['Dept_hour']=final_df['Dept_hour'].astype(int)
final_df['Dept_min']=final_df['Dept_min'].astype(int)
final_df.drop('Dep_Time',axis=1,inplace=True)

# %%
final_df.head(2)
# Out:
#      Airline    Source Destination                  Route Duration  \
# 0     IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1  Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
#
#   Total_Stops Additional_Info   Price  Date  Month  Year  Arrival_Hour  \
# 0    non-stop         No info  3897.0    24      3  2019             1
# 1     2 stops         No info  7662.0     1      5  2019            13
#
#    Arrival_min  Dept_hour  Dept_min
# 0           10         22        20
# 1           15          5        50

# %%
## total_stops

# %%
final_df['Total_Stops'] = final_df['Total_Stops'].map( {'non-stop':0,'1 stop':1,'2 stops':2,'3 stops':3,'4 stops':4,'nan':1} )

# %%
final_df.head(2)
# Out:
#      Airline    Source Destination                  Route Duration  \
# 0     IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1  Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
#
#    Total_Stops Additional_Info   Price  Date  Month  Year  Arrival_Hour  \
# 0          0.0         No info  3897.0    24      3  2019             1
# 1          2.0         No info  7662.0     1      5  2019            13
#
#    Arrival_min  Dept_hour  Dept_min
# 0           10         22        20
# 1           15          5        50

# %%
final_df.drop('Route' , axis=1 , inplace=True)

# %%
final_df.head(2)
# Out:
#      Airline    Source Destination Duration  Total_Stops Additional_Info  \
# 0     IndiGo  Banglore   New Delhi   2h 50m          0.0         No info
# 1  Air India   Kolkata    Banglore   7h 25m          2.0         No info
#
#     Price  Date  Month  Year  Arrival_Hour  Arrival_min  Dept_hour  Dept_min
# 0  3897.0    24      3  2019             1           10         22        20
# 1  7662.0     1      5  2019            13           15          5        50

# %%
set(final_df['Additional_Info'])
# Out:
# {'1 Long layover',
#  '1 Short layover',
#  '2 Long layover',
#  'Business class',
#  'Change airports',
#  'In-flight meal not included',
#  'No Info',
#  'No check-in baggage included',
#  'No info',
#  'Red-eye flight'}

# %%
## Duration column we will convert into minutes

# %%
final_df.head(3)
# Out:
#        Airline    Source Destination Arrival_Time Duration  Total_Stops  \
# 0       IndiGo  Banglore   New Delhi        01:10   2h 50m          0.0
# 1    Air India   Kolkata    Banglore        13:15   7h 25m          2.0
# 2  Jet Airways     Delhi      Cochin        04:25      19h          2.0
#
#   Additional_Info    Price  Date  Month  Year  Arrival_Hour  Arrival_min  \
# 0         No info   3897.0    24      3  2019             1           10
# 1         No info   7662.0     1      5  2019            13           15
# 2         No info  13882.0     9      6  2019             4           25
#
#    Dept_hour  Dept_min
# 0         22        20
# 1          5        50
# 2          9        25

# %%
final_df['Duration'].head(10)
# Out:
# 0     2h 50m
# 1     7h 25m
# 2        19h
# 3     5h 25m
# 4     4h 45m
# 5     2h 25m
# 6    15h 30m
# 7     21h 5m
# 8    25h 30m
# 9     7h 50m
# Name: Duration, dtype: object

# %%
final_df['Duration'].str.split(' ').str[0]
# Out:
# 0         2h
# 1         7h
# 2        19h
# 3         5h
# 4         4h
#         ...
# 13349    23h
# 13350     2h
# 13351     6h
# 13352    15h
# 13353    14h
# Name: Duration, Length: 13354, dtype: object

# %%
final_df['Duration'].str.split(' ').str[0].str.split('h').str[0]
# Out:
# 0         2
# 1         7
# 2        19
# 3         5
# 4         4
#          ..
# 13349    23
# 13350     2
# 13351     6
# 13352    15
# 13353    14
# Name: Duration, Length: 13354, dtype: object

# %%
final_df['duration_hour']=final_df['Duration'].str.split(' ').str[0].str.split('h').str[0]

# %%
final_df.head()
# Out:
#        Airline    Source Destination Duration  Total_Stops Additional_Info  \
# 0       IndiGo  Banglore   New Delhi   2h 50m          0.0         No info
# 1    Air India   Kolkata    Banglore   7h 25m          2.0         No info
# 2  Jet Airways     Delhi      Cochin      19h          2.0         No info
# 3       IndiGo   Kolkata    Banglore   5h 25m          1.0         No info
# 4       IndiGo  Banglore   New Delhi   4h 45m          1.0         No info
#
#      Price  Date  Month  Year  Arrival_Hour  Arrival_min  Dept_hour  Dept_min  \
# 0   3897.0    24      3  2019             1           10         22        20
# 1   7662.0     1      5  2019            13           15          5        50
# 2  13882.0     9      6  2019             4           25          9        25
# 3   6218.0    12      5  2019            23           30         18         5
# 4  13302.0     1      3  2019            21           35         16        50
#
#   duration_hour
# 0             2
# ...

# %%
final_df['duration_hour'] = final_df['duration_hour'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[178], line 1
# ----> 1 final_df['duration_hour'] = final_df['duration_hour'].astype(int)
#
# File c:\Users\Jayraj\anaconda3\Lib\site-packages\pandas\core\generic.py:6534, in NDFrame.astype(self, dtype, copy, errors)
#    6530     results = [ser.astype(dtype, copy=copy) for _, ser in self.items()]
#    6532 else:
#    6533     # else, only a single dtype is given
# -> 6534     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6535     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6536     return res.__finalize__(self, method="astype")
#
# File c:\Users\Jayraj\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:414, in BaseBlockManager.astype(self, dtype, copy, errors)
#     411 elif using_copy_on_write():
#     412     copy = False
# --> 414 return self.apply(
# ...

# %%
final_df['duration_hour'] == '5m'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 13349    False
# 13350    False
# 13351    False
# 13352    False
# 13353    False
# Name: duration_hour, Length: 13354, dtype: bool

# %%
final_df[final_df['duration_hour'] == '5m']  # here is mistke present
# Out:
#          Airline  Source Destination Duration  Total_Stops Additional_Info  \
# 6474   Air India  Mumbai   Hyderabad       5m          2.0         No info
# 13343  Air India  Mumbai   Hyderabad       5m          2.0         No info
#
#          Price  Date  Month  Year  Arrival_Hour  Arrival_min  Dept_hour  \
# 6474   17327.0     6      3  2019            16           55         16
# 13343      NaN    12      3  2019            16           55         16
#
#        Dept_min duration_hour
# 6474         50            5m
# 13343        50            5m

# %%
final_df.drop(6474 , axis=0 , inplace=True) 
final_df.drop(13343 , axis=0 , inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[182], line 1
# ----> 1 final_df.drop(6474 , axis=0 , inplace=True)
#       2 final_df.drop(13343 , axis=0 , inplace=True)
#
# File c:\Users\Jayraj\anaconda3\Lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
# ...

# %%
final_df['duration_hour'] = final_df['duration_hour'].astype(int)

# %%
final_df.head()
# Out:
#        Airline    Source Destination Arrival_Time Duration  Total_Stops  \
# 0       IndiGo  Banglore   New Delhi        01:10   2h 50m          0.0
# 1    Air India   Kolkata    Banglore        13:15   7h 25m          2.0
# 2  Jet Airways     Delhi      Cochin        04:25      19h          2.0
# 3       IndiGo   Kolkata    Banglore        23:30   5h 25m          1.0
# 4       IndiGo  Banglore   New Delhi        21:35   4h 45m          1.0
#
#   Additional_Info    Price  Date  Month  Year  Arrival_Hour  Arrival_min  \
# 0         No info   3897.0    24      3  2019             1           10
# 1         No info   7662.0     1      5  2019            13           15
# 2         No info  13882.0     9      6  2019             4           25
# 3         No info   6218.0    12      5  2019            23           30
# 4         No info  13302.0     1      3  2019            21           35
#
#    Dept_hour  Dept_min duration_hour
# 0         22        20             2
# ...

# %%
# final_df['duration_hour'] = final_df['duration_hour']*60

# %%
final_df.head()
# Out:
#        Airline    Source Destination Arrival_Time Duration  Total_Stops  \
# 0       IndiGo  Banglore   New Delhi        01:10   2h 50m          0.0
# 1    Air India   Kolkata    Banglore        13:15   7h 25m          2.0
# 2  Jet Airways     Delhi      Cochin        04:25      19h          2.0
# 3       IndiGo   Kolkata    Banglore        23:30   5h 25m          1.0
# 4       IndiGo  Banglore   New Delhi        21:35   4h 45m          1.0
#
#   Additional_Info    Price  Date  Month  Year  Arrival_Hour  Arrival_min  \
# 0         No info   3897.0    24      3  2019             1           10
# 1         No info   7662.0     1      5  2019            13           15
# 2         No info  13882.0     9      6  2019             4           25
# 3         No info   6218.0    12      5  2019            23           30
# 4         No info  13302.0     1      3  2019            21           35
#
#    Dept_hour  Dept_min  duration_hour
# 0         22        20            120
# ...

# %%
# final_df['duration_hour'] = final_df['duration_hour'] + final_df['Duration'].dt.minute
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[119], line 1
# ----> 1 final_df['duration_hour'] = final_df['duration_hour'] + final_df['Duration'].dt.minute
#
# File c:\Users\Jayraj\anaconda3\Lib\site-packages\pandas\core\generic.py:6204, in NDFrame.__getattr__(self, name)
#    6197 if (
#    6198     name not in self._internal_names_set
#    6199     and name not in self._metadata
#    6200     and name not in self._accessors
#    6201     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202 ):
#    6203     return self[name]
# -> 6204 return object.__getattribute__(self, name)
#
# File c:\Users\Jayraj\anaconda3\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# ...

# %%
# Assuming final_df is your DataFrame with the 'Duration' column
final_df['Duration_minutes'] = final_df['Duration'].dt.hour * 60 + final_df['Duration'].dt.minute

# Print the resulting DataFrame with the new 'Duration_minutes' column
print(final_df[['Duration', 'Duration_minutes']])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[184], line 2
#       1 # Assuming final_df is your DataFrame with the 'Duration' column
# ----> 2 final_df['Duration_minutes'] = final_df['Duration'].dt.hour * 60 + final_df['Duration'].dt.minute
#       4 # Print the resulting DataFrame with the new 'Duration_minutes' column
#       5 print(final_df[['Duration', 'Duration_minutes']])
#
# File c:\Users\Jayraj\anaconda3\Lib\site-packages\pandas\core\generic.py:6204, in NDFrame.__getattr__(self, name)
#    6197 if (
#    6198     name not in self._internal_names_set
#    6199     and name not in self._metadata
#    6200     and name not in self._accessors
#    6201     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202 ):
#    6203     return self[name]
# -> 6204 return object.__getattribute__(self, name)
#
# ...

# %%
import pandas as pd

# Assuming final_df is your DataFrame with the 'Duration' column
# Convert the 'Duration' column to datetime format
final_df['Duration'] = pd.to_datetime(final_df['Duration'], format='%Hh %Mm', errors='coerce')

# Extract hours and minutes
final_df['Duration_minutes'] = final_df['Duration'].dt.hour * 60 + final_df['Duration'].dt.minute

# Print the resulting DataFrame with the new 'Duration_minutes' column
print(final_df[['Duration', 'Duration_minutes']])
# Out:
#                  Duration  Duration_minutes
# 0     1900-01-01 02:50:00             170.0
# 1     1900-01-01 07:25:00             445.0
# 2                     NaT               NaN
# 3     1900-01-01 05:25:00             325.0
# 4     1900-01-01 04:45:00             285.0
# ...                   ...               ...
# 13349 1900-01-01 23:55:00            1435.0
# 13350 1900-01-01 02:35:00             155.0
# 13351 1900-01-01 06:35:00             395.0
# 13352 1900-01-01 15:15:00             915.0
# 13353 1900-01-01 14:20:00             860.0
#
# [13352 rows x 2 columns]

# %%
final_df.head(3)
# Out:
#        Airline    Source Destination            Duration  Total_Stops  \
# 0       IndiGo  Banglore   New Delhi 1900-01-01 02:50:00          0.0
# 1    Air India   Kolkata    Banglore 1900-01-01 07:25:00          2.0
# 2  Jet Airways     Delhi      Cochin                 NaT          2.0
#
#   Additional_Info    Price  Date  Month  Year  Arrival_Hour  Arrival_min  \
# 0         No info   3897.0    24      3  2019             1           10
# 1         No info   7662.0     1      5  2019            13           15
# 2         No info  13882.0     9      6  2019             4           25
#
#    Dept_hour  Dept_min  duration_hour  Duration_minutes
# 0         22        20              2             170.0
# 1          5        50              7             445.0
# 2          9        25             19               NaN

# %%
set(final_df['Airline'])
# Out:
# {'Air Asia',
#  'Air India',
#  'GoAir',
#  'IndiGo',
#  'Jet Airways',
#  'Jet Airways Business',
#  'Multiple carriers',
#  'Multiple carriers Premium economy',
#  'SpiceJet',
#  'Trujet',
#  'Vistara',
#  'Vistara Premium economy'}

# %%
from sklearn.preprocessing import LabelEncoder 

labelEncoder = LabelEncoder()

# %%
final_df['Airline']= labelEncoder.fit_transform(final_df['Airline'])

# %%
final_df.head()
# Out:
#    Airline    Source Destination            Duration  Total_Stops  \
# 0        3  Banglore   New Delhi 1900-01-01 02:50:00          0.0
# 1        1   Kolkata    Banglore 1900-01-01 07:25:00          2.0
# 2        4     Delhi      Cochin                 NaT          2.0
# 3        3   Kolkata    Banglore 1900-01-01 05:25:00          1.0
# 4        3  Banglore   New Delhi 1900-01-01 04:45:00          1.0
#
#   Additional_Info    Price  Date  Month  Year  Arrival_Hour  Arrival_min  \
# 0         No info   3897.0    24      3  2019             1           10
# 1         No info   7662.0     1      5  2019            13           15
# 2         No info  13882.0     9      6  2019             4           25
# 3         No info   6218.0    12      5  2019            23           30
# 4         No info  13302.0     1      3  2019            21           35
#
#    Dept_hour  Dept_min  duration_hour  Duration_minutes
# 0         22        20              2             170.0
# ...

# %%
final_df['Source']= labelEncoder.fit_transform(final_df['Source'])
final_df['Destination']= labelEncoder.fit_transform(final_df['Destination'])
final_df['Additional_Info']= labelEncoder.fit_transform(final_df['Additional_Info'])

# %%
final_df.shape
# Out:
# (13352, 16)

# %%
final_df.drop('Duration'  , axis=1 , inplace=True)

# %%
final_df.isnull().sum()
# Out:
# Airline                0
# Source                 0
# Destination            0
# Total_Stops            1
# Additional_Info        0
# Price               2670
# Date                   0
# Month                  0
# Year                   0
# Arrival_Hour           0
# Arrival_min            0
# Dept_hour              0
# Dept_min               0
# duration_hour          0
# Duration_minutes    2511
# dtype: int64

# %%
pd.get_dummies(final_df,columns=["Airline", "Source", "Destination"] ,drop_first = True)
# Out:
#        Total_Stops  Additional_Info    Price  Date  Month  Year  Arrival_Hour  \
# 0              0.0                8   3897.0    24      3  2019             1
# 1              2.0                8   7662.0     1      5  2019            13
# 2              2.0                8  13882.0     9      6  2019             4
# 3              1.0                8   6218.0    12      5  2019            23
# 4              1.0                8  13302.0     1      3  2019            21
# ...            ...              ...      ...   ...    ...   ...           ...
# 13349          1.0                8      NaN     6      6  2019            20
# 13350          0.0                8      NaN    27      3  2019            16
# 13351          1.0                8      NaN     6      3  2019             4
# 13352          1.0                8      NaN     6      3  2019            19
# 13353          1.0                8      NaN    15      6  2019            19
#
# ...

# %%
final_df.head()
# Out:
#    Airline  Source  Destination  Total_Stops  Additional_Info    Price  Date  \
# 0        3       0            5          0.0                8   3897.0    24
# 1        1       3            0          2.0                8   7662.0     1
# 2        4       2            1          2.0                8  13882.0     9
# 3        3       3            0          1.0                8   6218.0    12
# 4        3       0            5          1.0                8  13302.0     1
#
#    Month  Year  Arrival_Hour  Arrival_min  Dept_hour  Dept_min  duration_hour  \
# 0      3  2019             1           10         22        20              2
# 1      5  2019            13           15          5        50              7
# 2      6  2019             4           25          9        25             19
# 3      5  2019            23           30         18         5              5
# 4      3  2019            21           35         16        50              4
#
#    Duration_minutes
# ...
